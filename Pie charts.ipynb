# %%
import matplotlib.pyplot as plt

labels = ['Green', 'Red', 'Black', 'Yellow']
sizes = [38.4, 40.6, 20.7, 10.3]
colors = ['green', 'red', 'black', 'yellow']
patches, texts = plt.pie(sizes, colors=colors)
plt.legend(patches, labels, loc="best")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
# library
import pandas as pd
 
df = pd.DataFrame([38.4, 40.6, 20.7, 10.3], index=['blue', 'orange', 'green', 'red'], columns=['pie chart'])
 
# make the plot
df.plot(kind='pie', subplots=True, figsize=(8, 8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001F13670AB38>],
#       dtype=object)
